# %%
# import important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read files from internal storage
df_1 = pd.read_csv('D:/ASIGMENT 5/takehome_user_engagement.csv')
df_2 = pd.read_csv('D:/ASIGMENT 5/takehome_users.csv', encoding='latin-1')

# %%
# check data of first data frame
df_1.head(3)
# Out:
#             time_stamp  user_id  visited
# 0  2014-04-22 03:53:30        1        1
# 1  2013-11-15 03:45:04        2        1
# 2  2013-11-29 03:45:04        2        1

# %%
# check data of second data frame
df_2.head(3)
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# 2                         0                           0      94
#
#    invited_by_user_id
# 0             10803.0
# 1               316.0
# 2              1525.0

# %%
# merge both data frame and put in new data frame
df = df_2.join(df_1)
df.head(3)
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# 2                         0                           0      94
#
#    invited_by_user_id           time_stamp  user_id  visited
# 0             10803.0  2014-04-22 03:53:30        1        1
# 1               316.0  2013-11-15 03:45:04        2        1
# ...

# %%
# create last login column from time stamp column and change into datetime formate
df['last_login'] = df['time_stamp'].str.split(' ').str[0]
df['last_login'] = pd.to_datetime(df['last_login'], format='%Y-%m-%d')

# %%
# check new data created data frame
df.head(3)
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# 2                         0                           0      94
#
#    invited_by_user_id  user_id  visited last_login     last_login_time
# 0             10803.0        1        1 2014-04-22 2022-05-15 03:53:30
# ...

# %%
# run a for loop for getting only users who login in a product three different days
x = []
y = []
z = []
a = []
b = []
for i in new_df['name']:
    x.append(i)
for j,k,l,m in zip(x, new_df['last_login'], new_df['creation_source'],new_df['email']):
    if x.count(j)>2:
        y.append(j)
        z.append(k)
        a.append(l)
        b.append(m)

# %%
# create a new data frame for answer the question
new_df = pd.DataFrame()

# %%
# insert values to the new data frame
new_df['Name'] = y
new_df['Last_Login'] = z
new_df['Entry_Type'] = a
new_df['Email']  = b

# %%
# sorting values by name in ascending order
new_df = new_df_2.sort_values('Name', ascending=True)
new_df.head(3)
# Out:
#               Name Last_Login          Entry_Type  \
# 57  Almeida Arthur 2014-01-23  SIGNUP_GOOGLE_AUTH
# 64  Almeida Arthur 2014-02-06          ORG_INVITE
# 95  Almeida Arthur 2013-10-21          ORG_INVITE
#
#                                Email
# 57      ArthurPintoAlmeida@gmail.com
# 64  ArthurRodriguesAlmeida@gmail.com
# 95                tnklzpbi@ovoiw.com

# %%
# users login by different days
adopted_user = new_df.groupby(['Name', 'Last_Login']).first()
adopted_user.head(20)
# Out:
#                                     Entry_Type  \
# Name            Last_Login
# Almeida Arthur  2013-10-21          ORG_INVITE
#                 2014-01-23  SIGNUP_GOOGLE_AUTH
#                 2014-02-06          ORG_INVITE
# Almeida Nicolas 2013-08-06          ORG_INVITE
#                 2013-12-30   PERSONAL_PROJECTS
#                 2014-03-22          ORG_INVITE
# Almeida Thiago  2013-09-10   PERSONAL_PROJECTS
#                 2014-04-02        GUEST_INVITE
#                 2014-05-07        GUEST_INVITE
# Alves Gabrielly 2013-10-24          ORG_INVITE
#                 2014-01-01  SIGNUP_GOOGLE_AUTH
#                 2014-01-09   PERSONAL_PROJECTS
# Araujo Gabriela 2013-06-05   PERSONAL_PROJECTS
#                 2013-07-08          ORG_INVITE
#                 2013-08-28        GUEST_INVITE
#                 2013-10-18          ORG_INVITE
#                 2013-11-23              SIGNUP
# Araujo Leonardo 2013-03-22          ORG_INVITE
# ...

# %% [markdown]
# # ANALYSIS OF  OTHER DATA

# %%
df.head(3)
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# 2                         0                           0      94
#
#    invited_by_user_id           time_stamp  user_id  visited last_login
# 0             10803.0  2014-04-22 03:53:30        1        1 2014-04-22
# ...

# %%
df.creation_source.value_counts().plot(kind = 'barh')
plt.title('Creation Source', fontsize = 22)
plt.xlabel('Login Count', fontsize = 18)
plt.ylabel('Login Type', fontsize = 18)
plt.show()
